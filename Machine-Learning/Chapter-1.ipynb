# %% [markdown]
# ## **What we will cover in this notebook**
# 1. Linear Regression.
# 2. Logistic Regression.
# 3. Regularization (lasso, Ridge, elastic net)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# > 🔑: https://scikit-learn.org/stable/modules/linear_model.html

# %%
X_reg, y_reg = make_regression(n_samples=200, n_features=1, noise=15, random_state=42)

# %%
X_reg
# Out:
# array([[ 1.85227818],
#        [ 0.47359243],
#        [-1.23086432],
#        [ 0.62566735],
#        [-0.07201012],
#        [ 0.81252582],
#        [-0.18565898],
#        [-0.81581028],
#        [ 0.06023021],
#        [ 0.65655361],
#        [ 2.46324211],
#        [ 1.0035329 ],
#        [-0.26465683],
#        [-0.23458713],
#        [-0.56228753],
#        [ 0.29698467],
#        [ 0.08704707],
#        [ 1.45353408],
#        [-0.97468167],
#        [-1.4123037 ],
#        [-0.50347565],
#        [-0.07710171],
#        [ 0.38531738],
#        [-1.40185106],
#        [-0.07282891],
#        [ 0.34115197],
#        [ 0.8219025 ],
#        [-0.44651495],
#        [-0.46947439],
#        [ 1.86577451],
#        [-1.42474819],
#        [-0.60170661],
#        [ 0.82254491],
#        [-0.46341769],
#        [ 0.96337613],
#        [ 1.52302986],
#        [-0.5297602 ],
#        [-1.32045661],
#        [-0.99053633],
#        [ 0.15372511],
#        [-0.01349722],
# ...

# %%
y_reg
# Out:
# array([ 143.45082298,   54.63984844,  -84.44223644,   59.32653116,
#          -8.24415636,   94.43484246,  -17.86599624,  -66.1398507 ,
#           1.2188295 ,   85.50375075,  206.92180967,   81.06230257,
#         -24.32444462,  -38.89059495,  -46.69087985,   13.3945818 ,
#         -20.82337937,  125.54467418,  -67.50977189, -136.75065746,
#         -23.80538631,    1.80551629,    9.81985722, -123.12689303,
#         -19.90921996,   44.48961291,   74.00293493,  -35.28517988,
#         -40.8314412 ,  197.8344509 , -119.64400116,  -44.5484727 ,
#          92.619408  ,  -19.09867555,   62.73128551,  154.35660744,
#         -55.81329121, -114.5202124 ,  -91.54337748,   21.51980399,
#          34.65132921,   79.49600077,   48.02267244,  136.2563509 ,
#          29.28099845, -104.61088869,   18.55227857,  -57.35981978,
#         -10.00159386,  -77.19224528,   24.10959789, -151.27138937,
#           7.84352851,  -26.36643326,    0.950624  ,  118.34204017,
# ...

# %%
len(X_reg)
# Out:
# 200

# %%
X_train, X_test, y_train, y_test = train_test_split(X_reg, y_reg, test_size=0.2, random_state=42)
X_train
# Out:
# array([[ 0.0675282 ],
#        [ 1.53803657],
#        [-0.99053633],
#        [-0.07282891],
#        [-0.16128571],
#        [ 0.2322537 ],
#        [ 1.86577451],
#        [-1.4123037 ],
#        [ 0.05820872],
#        [-0.1382643 ],
#        [-1.47852199],
#        [-1.51484722],
#        [ 0.81252582],
#        [ 0.81351722],
#        [ 0.34361829],
#        [-0.71435142],
#        [-1.1913035 ],
#        [ 2.72016917],
#        [ 0.26105527],
#        [ 0.82206016],
#        [ 0.09176078],
#        [ 1.89679298],
#        [-0.60170661],
#        [-0.26465683],
#        [ 1.52302986],
#        [-0.71984421],
#        [ 0.75193303],
#        [-1.76304016],
#        [ 0.37569802],
#        [-1.46351495],
#        [-1.60748323],
#        [-0.2257763 ],
#        [ 0.32408397],
#        [ 1.03099952],
#        [ 0.34644821],
#        [-1.15099358],
#        [ 0.8219025 ],
#        [-0.80227727],
#        [-1.22084365],
#        [ 0.11092259],
#        [-1.23086432],
# ...

# %%
# Models
models_reg = {
    "LinearRegression": LinearRegression(),
    "Ridge": Ridge(alpha=0.1),
    "Lasso": Lasso(alpha=0.1),
    "ElaticNet": ElasticNet(alpha=0.1, l1_ratio=0.9)
}
for cle, value in models_reg.items():
  value.fit(X_train, y_train)
  y_pred = value.predict(X_test)
  mse = mean_squared_error(y_test, y_pred)
  print(f"{cle} Regression - MSE: {mse:.3f}")
# Out:
# LinearRegression Regression - MSE: 246.122
# Ridge Regression - MSE: 246.323
# Lasso Regression - MSE: 246.499
# ElaticNet Regression - MSE: 250.818

# %% [markdown]
# > 🔑: https://www.w3schools.com/python/python_ref_dictionary.asp

# %%
x_line = np.linspace(X_test.min(), X_test.max(), 100)
x_line
# Out:
# array([-2.6197451 , -2.57115722, -2.52256933, -2.47398145, -2.42539356,
#        -2.37680567, -2.32821779, -2.2796299 , -2.23104201, -2.18245413,
#        -2.13386624, -2.08527836, -2.03669047, -1.98810258, -1.9395147 ,
#        -1.89092681, -1.84233893, -1.79375104, -1.74516315, -1.69657527,
#        -1.64798738, -1.59939949, -1.55081161, -1.50222372, -1.45363584,
#        -1.40504795, -1.35646006, -1.30787218, -1.25928429, -1.21069641,
#        -1.16210852, -1.11352063, -1.06493275, -1.01634486, -0.96775697,
#        -0.91916909, -0.8705812 , -0.82199332, -0.77340543, -0.72481754,
#        -0.67622966, -0.62764177, -0.57905389, -0.530466  , -0.48187811,
#        -0.43329023, -0.38470234, -0.33611445, -0.28752657, -0.23893868,
#        -0.1903508 , -0.14176291, -0.09317502, -0.04458714,  0.00400075,
#         0.05258863,  0.10117652,  0.14976441,  0.19835229,  0.24694018,
#         0.29552807,  0.34411595,  0.39270384,  0.44129172,  0.48987961,
# ...

# %%
x_line = np.linspace(X_test.min(), X_test.max(), 100).reshape(-1,1)
x_line
# Out:
# array([[-2.6197451 ],
#        [-2.57115722],
#        [-2.52256933],
#        [-2.47398145],
#        [-2.42539356],
#        [-2.37680567],
#        [-2.32821779],
#        [-2.2796299 ],
#        [-2.23104201],
#        [-2.18245413],
#        [-2.13386624],
#        [-2.08527836],
#        [-2.03669047],
#        [-1.98810258],
#        [-1.9395147 ],
#        [-1.89092681],
#        [-1.84233893],
#        [-1.79375104],
#        [-1.74516315],
#        [-1.69657527],
#        [-1.64798738],
#        [-1.59939949],
#        [-1.55081161],
#        [-1.50222372],
#        [-1.45363584],
#        [-1.40504795],
#        [-1.35646006],
#        [-1.30787218],
#        [-1.25928429],
#        [-1.21069641],
#        [-1.16210852],
#        [-1.11352063],
#        [-1.06493275],
#        [-1.01634486],
#        [-0.96775697],
#        [-0.91916909],
#        [-0.8705812 ],
#        [-0.82199332],
#        [-0.77340543],
#        [-0.72481754],
#        [-0.67622966],
# ...

# %%
plt.figure(figsize=(10,6))
plt.scatter(X_test, y_test, color ='gray', label = 'data')
x_line = np.linspace(X_test.min(), X_test.max(), 100).reshape(-1,1)

for cle, value in models_reg.items():
  y_line = value.predict(x_line)
  plt.plot(x_line, y_line, label= value)

plt.title("Linear Regression models with Regularization")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.show()

# %% [markdown]
# > 🔑: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html
#   🔑: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html
