# %%
import numpy as np

# %%
arr1 = np.array([1,2,3,4,5])
arr1
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr2 = np.array([[1,2,3],
                 [2.5,8,9]])
arr2
# Out:
# array([[1. , 2. , 3. ],
#        [2.5, 8. , 9. ]])

# %%
arr1.dtype , arr2.dtype
# Out:
# (dtype('int64'), dtype('float64'))

# %%
arr1.shape , arr2.shape
# Out:
# ((5,), (2, 3))

# %%
arr1.ndim ,arr2.ndim
# Out:
# (1, 2)

# %%
type(arr1) , type(arr2)
## ndarry is type of all array no matter what's datatype of array integer , float.
# Out:
# (numpy.ndarray, numpy.ndarray)

# %% [markdown]
# **Creat a DataFrame from array numpy**

# %%
import pandas as pd

# %%
df = pd.DataFrame(arr2)
df
### This is important when you have a data not numercil i mean images so you convert these to numpy array and use pandas and matplotlib and machine learning model.
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  2.5  8.0  9.0

# %%
ones = np.ones((2,4),dtype = int)
ones
# Out:
# array([[1, 1, 1, 1],
#        [1, 1, 1, 1]])

# %%
zeros = np.zeros((2,3),dtype = float)
zeros
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
range_array = np.arange(0,10,2)
range_array
# Out:
# array([0, 2, 4, 6, 8])

# %%
random_array = np.random.randint(0,10,size = (4,4))
random_array
# Out:
# array([[1, 1, 3, 1],
#        [1, 1, 8, 1],
#        [3, 7, 4, 5],
#        [3, 6, 9, 4]])

# %%
random_array.dtype
# Out:
# dtype('int64')

# %%
random_array2 = np.random.random((5,3))
random_array2
# Out:
# array([[0.2691943 , 0.4941011 , 0.87372318],
#        [0.46318098, 0.02640927, 0.81403929],
#        [0.04872102, 0.56748965, 0.78911074],
#        [0.01408716, 0.11533022, 0.77339212],
#        [0.33520724, 0.78450658, 0.19582691]])

# %%
random_array3 = np.random.rand(5,3)
random_array3
# Out:
# array([[0.43197894, 0.83042106, 0.48562035],
#        [0.16622693, 0.0474907 , 0.19705371],
#        [0.27371532, 0.64492341, 0.18837774],
#        [0.34431603, 0.84674337, 0.26028141],
#        [0.14863434, 0.61676629, 0.19127664]])

# %%
# pesudo_random numbers
np.random.seed(seed = 0)
random_array4 = np.random.randint(10,size = (2,2))
random_array4
# Out:
# array([[5, 0],
#        [3, 3]])

# %%
np.unique(random_array4)
# Out:
# array([0, 3, 5])

# %%
# arr2
arr2[0][1] = 100

# %%
arr2
# Out:
# array([[  1. , 100. ,   3. ],
#        [  2.5,   8. ,   9. ]])

# %% [markdown]
# ** Matrix Operations**

# %%
matrix1 = np.array([[1, 3],
                   [5, 7]])
matrix2 = np.array([[2, 4],
                   [6, 8]])

# %%
matrix1 * matrix2
# Out:
# array([[ 2, 12],
#        [30, 56]])

# %%
matrix2 * matrix1
# Out:
# array([[ 2, 12],
#        [30, 56]])

# %%
2 * matrix1
# Out:
# array([[ 2,  6],
#        [10, 14]])

# %%
matrix1 / matrix2
# Out:
# array([[0.5       , 0.75      ],
#        [0.83333333, 0.875     ]])

# %% [markdown]
# # Use Python's methods (sum()) on Python datatypes and use Numpy's methods on Numpy arrays(np.sum()).

# %%
random_array3
# Out:
# array([[0.43197894, 0.83042106, 0.48562035],
#        [0.16622693, 0.0474907 , 0.19705371],
#        [0.27371532, 0.64492341, 0.18837774],
#        [0.34431603, 0.84674337, 0.26028141],
#        [0.14863434, 0.61676629, 0.19127664]])

# %%
# %timeit sum(random_array3)
# %timeit np.sum(random_array3)
# Out:
# 12 µs ± 5.13 µs per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# The slowest run took 5.05 times longer than the fastest. This could mean that an intermediate result is being cached.
# 9.88 µs ± 4.99 µs per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
arr2
# Out:
# array([[  1. , 100. ,   3. ],
#        [  2.5,   8. ,   9. ]])

# %%
np.max(arr2)
# Out:
# 100.0

# %%
np.std(arr2)
# Out:
# 35.63520808912943

# %%
np.var(arr2)
# Out:
# 1269.8680555555557

# %%
np.median(arr2)
# Out:
# 5.5

# %%
arr2.transpose()
# Out:
# array([[  1. ,   2.5],
#        [100. ,   8. ],
#        [  3. ,   9. ]])

# %% [markdown]
# **Dot Product**

# %%
np.random.seed(0)
mat1 = np.random.randint(10,size = (5,3))
mat2 = np.random.randint(10,size = (5,3))

# %%
mat2.transpose()
# Out:
# array([[6, 8, 9, 4, 3],
#        [7, 1, 8, 3, 5],
#        [7, 5, 9, 0, 0]])

# %%
mat1.dot(mat2.transpose())
# Out:
# array([[ 51,  55,  72,  20,  15],
#        [130,  76, 164,  33,  44],
#        [ 67,  39,  85,  27,  34],
#        [115,  69, 146,  37,  47],
#        [111,  77, 145,  56,  64]])

# %% [markdown]
# # **SORTING ARRAYS IN NUMPY**

# %%
random_array
# Out:
# array([[1, 1, 3, 1],
#        [1, 1, 8, 1],
#        [3, 7, 4, 5],
#        [3, 6, 9, 4]])

# %%
np.sort(random_array)
# Out:
# array([[1, 1, 1, 3],
#        [1, 1, 1, 8],
#        [3, 4, 5, 7],
#        [3, 4, 6, 9]])

# %%
np.argsort(random_array)
# Out:
# array([[0, 1, 3, 2],
#        [0, 1, 3, 2],
#        [0, 2, 3, 1],
#        [0, 3, 1, 2]])

# %%
np.argmax(random_array)
# Out:
# 14

# %%
np.argmin(random_array)
# Out:
# 0

# %%
np.argsort(random_array, axis =0)
# Out:
# array([[0, 0, 0, 0],
#        [1, 1, 2, 1],
#        [2, 3, 1, 3],
#        [3, 2, 3, 2]])

# %%
random_array
# Out:
# array([[1, 1, 3, 1],
#        [1, 1, 8, 1],
#        [3, 7, 4, 5],
#        [3, 6, 9, 4]])

# %%
np.sort(random_array,axis = 0)
# Out:
# array([[1, 1, 3, 1],
#        [1, 1, 4, 1],
#        [3, 6, 8, 4],
#        [3, 7, 9, 5]])

# %%
m = np.array([[1,2,3],
             [-6,0,2],
             [7,8,0]])
m
# Out:
# array([[ 1,  2,  3],
#        [-6,  0,  2],
#        [ 7,  8,  0]])

# %%
np.sort(m, axis = 0)
# Out:
# array([[-6,  0,  0],
#        [ 1,  2,  2],
#        [ 7,  8,  3]])

# %%
# <img src="numpy-images/panda.png"/>
from google.colab import files
# drive.mount('/content/drive')
from IPython.display import Image
# Image('numpy-images/panda.png')

# %%
uploded = files.upload()
# Out:
#      <input type="file" id="files-b7d14579-4140-400c-a297-7c43e0166e31" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b7d14579-4140-400c-a297-7c43e0166e31">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('panda.png',
      width= 1200)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from matplotlib.image import imread
panda = imread('panda.png')

# %%
panda.shape , panda.size , panda.ndim
# Out:
# ((2330, 3500, 3), 24465000, 3)
