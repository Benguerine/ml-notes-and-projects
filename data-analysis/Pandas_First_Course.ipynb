# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
# 2 main datatype
car_Type = pd.Series(["bmw","audi","purche"])

# %%
print(car_Type)
# Out:
# 0       bmw
# 1      audi
# 2    purche
# dtype: object

# %%
#Series is for 1-dimensional

# %%
colours = pd.Series(["Bleu","Black","White"])

# %%
# DataFrame is for 2-dimensional

# %%
car_data = pd.DataFrame({"Car Mark" : car_Type , "colour" : colours})
car_data
# Out:
#   Car Mark colour
# 0      bmw   Bleu
# 1     audi  Black
# 2   purche  White

# %%
# Import data
import pandas as pd
path ="/content/drive/MyDrive/ml-notes/Data/car-sales.csv"
car_Sales = pd.read_csv (path)
car_Sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Exporting datafram
car_Sales.to_csv("exported-car-sales.csv", index = False)

# %%
exported_car_Sales = pd.read_csv("exported-car-sales.csv")
exported_car_Sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#Attribute
car_Sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_Sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_Sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_Sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_Sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
#car_Sales.median()
#car_Sales.mean()
#car_Sales.sum()
#car_Sales.mean(axis=1)
car_Sales.select_dtypes(include='number').mean()
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_Sales.select_dtypes(include='number').sum()
# Out:
# Odometer (KM)    786014
# Doors                40
# dtype: int64

# %%
car_Sales.select_dtypes(include='number').median()
# Out:
# Odometer (KM)    57369.0
# Doors                4.0
# dtype: float64

# %%
car_Sales.select_dtypes(include='number').mean(axis = 1)
# Out:
# 0     75023.5
# 1     43951.5
# 2     16276.0
# 3      5592.0
# 4    106549.5
# 5     49608.5
# 6     22851.0
# 7     27371.0
# 8     30002.0
# 9     15802.0
# dtype: float64

# %%
sales = pd.Series([3000,400015,55021])
sales
# Out:
# 0      3000
# 1    400015
# 2     55021
# dtype: int64

# %%
sales.sum()
# Out:
# np.int64(458036)

# %%
sales.mean()
# Out:
# np.float64(152678.66666666666)

# %%
sales.min()
# Out:
# 3000

# %%
car_Sales["Doors"].sum()
# Out:
# np.int64(40)

# %% [markdown]
# **Viewing And salecting data**

# %%
car_Sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_Sales.head(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_Sales.tail(4)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
#.loc
animales = pd.Series(["cat","panda","dog","lion"] , index =[0,3,9,11])
animales
# Out:
# 0       cat
# 3     panda
# 9       dog
# 11     lion
# dtype: object

# %%
animales.loc[11]
# Out:
# 'lion'

# %%
# .iloc
animales.iloc[1]
animales.iloc[2]
# Out:
# 'dog'

# %%
car_Sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_Sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_Sales[car_Sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_Sales["Make"],car_Sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Groupby
car_Sales.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_Sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_Sales["Price"] = car_Sales["Price"].str.replace('[\$\,\.]', '', regex=True).astype(int)

# %%
car_Sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_Sales["Price"].plot()
# Out:
# <Axes: >

# %%
path ="/content/drive/MyDrive/ml-notes/Data/car-sales.csv"
car_Sales = pd.read_csv (path)
car_Sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
path ="/content/drive/MyDrive/ml-notes/Data/car-sales.csv"
car_Sales = pd.read_csv (path)
car_Sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
path ="/content/drive/MyDrive/ml-notes/Data/car-sales-missing-data.csv"
car_Sales_missing = pd.read_csv(path)
car_Sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
path ="/content/drive/MyDrive/ml-notes/Data/car-sales-missing-data.csv"
car_Sales_missing = pd.read_csv(path)
car_Sales_missing
car_Sales_missing["Odometer"].fillna(car_Sales_missing["Odometer"].mean(), inplace=True)

# Display the modified DataFrame
car_Sales_missing
# Out:
# <ipython-input-100-1c7630c1cd8c>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_Sales_missing["Odometer"].fillna(car_Sales_missing["Odometer"].mean(), inplace=True)
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# ...

# %%
car_Sales_missing.dropna(inplace=True)

# %%
car_Sales_missing_dropped = car_Sales_missing.dropna()
car_Sales_missing_dropped
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_Sales_missing_dropped.to_csv("car-sales-missing-dropped.csv")

# %%
# Column from Series
seats_Column = pd.Series([4,3,4,5,4])
seats_Column
# Out:
# 0    4
# 1    3
# 2    4
# 3    5
# 4    4
# dtype: int64

# %%
# New Column called Seats
car_Sales["Seats"] = seats_Column
car_Sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    4.0
# 1   Honda    Red          87899      4   $5,000.00    3.0
# 2  Toyota   Blue          32549      3   $7,000.00    4.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    4.0
# 5  Toyota  Green          99213      4   $4,500.00    NaN
# 6   Honda   Blue          45698      4   $7,500.00    NaN
# 7   Honda   Blue          54738      4   $7,000.00    NaN
# 8  Toyota  White          60000      4   $6,250.00    NaN
# 9  Nissan  White          31600      4   $9,700.00    NaN

# %%
car_Sales["Seats"].fillna(4, inplace= True)
# Out:
# <ipython-input-106-54836a537cbf>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_Sales["Seats"].fillna(4, inplace= True)

# %%
car_Sales["Number Of Whelles"] = 4
car_Sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Number Of Whelles
# 0  Toyota  White         150043      4   $4,000.00    4.0                  4
# 1   Honda    Red          87899      4   $5,000.00    3.0                  4
# 2  Toyota   Blue          32549      3   $7,000.00    4.0                  4
# 3     BMW  Black          11179      5  $22,000.00    5.0                  4
# 4  Nissan  White         213095      4   $3,500.00    4.0                  4
# 5  Toyota  Green          99213      4   $4,500.00    4.0                  4
# 6   Honda   Blue          45698      4   $7,500.00    4.0                  4
# 7   Honda   Blue          54738      4   $7,000.00    4.0                  4
# 8  Toyota  White          60000      4   $6,250.00    4.0                  4
# 9  Nissan  White          31600      4   $9,700.00    4.0                  4

# %%
car_Sales_shuffled = car_Sales.sample(frac=1)

# %%
car_Sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Number Of Whelles
# 7   Honda   Blue          54738      4   $7,000.00    4.0                  4
# 3     BMW  Black          11179      5  $22,000.00    5.0                  4
# 6   Honda   Blue          45698      4   $7,500.00    4.0                  4
# 4  Nissan  White         213095      4   $3,500.00    4.0                  4
# 5  Toyota  Green          99213      4   $4,500.00    4.0                  4
# 8  Toyota  White          60000      4   $6,250.00    4.0                  4
# 0  Toyota  White         150043      4   $4,000.00    4.0                  4
# 9  Nissan  White          31600      4   $9,700.00    4.0                  4
# 2  Toyota   Blue          32549      3   $7,000.00    4.0                  4
# 1   Honda    Red          87899      4   $5,000.00    3.0                  4

# %%
# Only select 20% of dataset you can select 10% as you want
car_Sales_shuffled.sample(frac = 0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seats  Number Of Whelles
# 8  Toyota  White          60000      4  $6,250.00    4.0                  4
# 9  Nissan  White          31600      4  $9,700.00    4.0                  4

# %%
car_Sales_shuffled.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors       Price  Seats  \
# 0      7   Honda   Blue          54738      4   $7,000.00    4.0
# 1      3     BMW  Black          11179      5  $22,000.00    5.0
# 2      6   Honda   Blue          45698      4   $7,500.00    4.0
# 3      4  Nissan  White         213095      4   $3,500.00    4.0
# 4      5  Toyota  Green          99213      4   $4,500.00    4.0
# 5      8  Toyota  White          60000      4   $6,250.00    4.0
# 6      0  Toyota  White         150043      4   $4,000.00    4.0
# 7      9  Nissan  White          31600      4   $9,700.00    4.0
# 8      2  Toyota   Blue          32549      3   $7,000.00    4.0
# 9      1   Honda    Red          87899      4   $5,000.00    3.0
#
#    Number Of Whelles
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# 5                  4
# 6                  4
# 7                  4
# 8                  4
# 9                  4

# %%
car_Sales["Odometer (KM)"] = car_Sales["Odometer (KM)"].apply(lambda x: x/1.6)

# %%
car_Sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Number Of Whelles
# 0  Toyota  White      93776.875      4   $4,000.00    4.0                  4
# 1   Honda    Red      54936.875      4   $5,000.00    3.0                  4
# 2  Toyota   Blue      20343.125      3   $7,000.00    4.0                  4
# 3     BMW  Black       6986.875      5  $22,000.00    5.0                  4
# 4  Nissan  White     133184.375      4   $3,500.00    4.0                  4
# 5  Toyota  Green      62008.125      4   $4,500.00    4.0                  4
# 6   Honda   Blue      28561.250      4   $7,500.00    4.0                  4
# 7   Honda   Blue      34211.250      4   $7,000.00    4.0                  4
# 8  Toyota  White      37500.000      4   $6,250.00    4.0                  4
# 9  Nissan  White      19750.000      4   $9,700.00    4.0                  4
