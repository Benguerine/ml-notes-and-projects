# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Step 1: Set paths
folder_path = "/content/drive/MyDrive/ml-notes"  # change if needed
os.chdir(folder_path)

# Step 2: Git config
# !git init
# !git config --global user.email "mohammed.benguerine.1102@univ-sba.dz"
# !git config --global user.name "Benguerine"

from getpass import getpass

token = getpass('Enter your GitHub token: ')

# !git remote remove origin || true  # ignore error if origin doesn't exist
repo_url = f"https://{token}@github.com/Benguerine/ml-notes-and-projects.git"
# !git remote add origin {repo_url}

# !git add .
# !git commit -m "Initial commit from Colab"

# !git pull origin main --rebase
# !git branch -M main
# !git push -u origin main
