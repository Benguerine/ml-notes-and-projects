# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Step 1: Set paths
folder_path = "/content/drive/MyDrive/ml-notes"  # change if needed
os.chdir(folder_path)

# Step 2: Git config
# !git init
# !git config --global user.email "mohammed.benguerine.1102@univ-sba.dz"
# !git config --global user.name "Benguerine"

from getpass import getpass

token = getpass('Enter your GitHub token: ')

# !git remote remove origin || true  # ignore error if origin doesn't exist
repo_url = f"https://{token}@github.com/Benguerine/ml-notes-and-projects.git"
# !git remote add origin {repo_url}

# !git add .
# !git commit -m "Initial commit from Colab"

# !git pull origin main --rebase
# !git branch -M main
# !git push -u origin main
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/ml-notes/.git/
# Enter your GitHub token: ··········
# error: No such remote: 'origin'
# [master (root-commit) 2c21e8f] Initial commit from Colab
#  12 files changed, 2648 insertions(+)
#  create mode 100644 Copy of Copy of Git.ipynb
#  create mode 100644 Data/car-sales-extended-missing-data.csv
#  create mode 100644 Data/car-sales-extended.csv
#  create mode 100644 Data/car-sales-missing-data.csv
#  create mode 100644 Data/car-sales.csv
#  create mode 100644 Data/exported-car-sales.csv
#  create mode 100644 Data/exported-patient-data.csv
#  create mode 100644 Data/heart-disease.csv
#  create mode 100644 data-analysis/Matplotlib_Lessone.ipynb
#  create mode 100644 data-analysis/NumpyLessone.ipynb
#  create mode 100644 data-analysis/Pandas_First_Course.ipynb
#  create mode 100644 scikit-learn/Introduction-To-Scikit-learn.ipynb
# fatal: couldn't find remote ref main
# Enumerating objects: 17, done.
# Counting objects: 100% (17/17), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (17/17), done.
# Writing objects: 100% (17/17), 1.11 MiB | 1.95 MiB/s, done.
# Total 17 (delta 4), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (4/4), done.
# To https://github.com/Benguerine/ml-notes-and-projects.git
#  * [new branch]      main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
