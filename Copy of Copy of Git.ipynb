# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# Step 1: Set paths
folder_path = "/content/drive/MyDrive/ml-notes"  # change if needed
os.chdir(folder_path)

# Step 2: Git config
# !git init
# !git config --global user.email "mohammed.benguerine.1102@univ-sba.dz"
# !git config --global user.name "Benguerine"

from getpass import getpass

token = getpass('Enter your GitHub token: ')

# !git remote remove origin || true  # ignore error if origin doesn't exist
repo_url = f"https://{token}@github.com/Benguerine/ml-notes-and-projects.git"
# !git remote add origin {repo_url}

# !git add .
# !git commit -m "Initial commit from Colab"

# !git pull origin main --rebase
# !git branch -M main
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/ml-notes/.git/
# Enter your GitHub token: ··········
# [main 2f1563f] Initial commit from Colab
#  5 files changed, 5 insertions(+), 2 deletions(-)
#  rewrite data-analysis/Matplotlib_Lessone.ipynb (82%)
#  create mode 100644 notebook/Matplotlib_workshop.ipynb
#  create mode 100644 notebook/Pandas_Workshop.ipynb
#  create mode 100644 notebook/numpy_workshop.ipynb
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 6 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 2.37 KiB | 32.00 KiB/s, done.
# From https://github.com/Benguerine/ml-notes-and-projects
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main
# Successfully rebased and updated refs/heads/main.
# Enumerating objects: 13, done.
# Counting objects: 100% (13/13), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (9/9), 1.09 MiB | 2.46 MiB/s, done.
# Total 9 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 2 local objects.
# To https://github.com/Benguerine/ml-notes-and-projects.git
#    891d780..ed881c5  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
